# %% [markdown]
# tandem-x env
#
# # Notebook to load in a TANDEM-X and extract a catchment from the pour point
#
# The difficulty is I don't know the pour point, so I need to first find it and then apply it. For the artifcats in the DEM I used a Gaussian kernel with the `astropy` convolution function. This smoothes the whole DEM and fills the holes. Smoothing the DEM is a shame but filling the holes is a bonus. Void filling using GANs would be better (https://arxiv.org/pdf/1811.12693.pdf) but this is beyond my pay scale. I then turn to `pysheds` to extract the Kauley Khola catchment from my DEM. (Watch out for this issue though: https://github.com/mdbartos/pysheds/issues/10).

# %%
import os, sys
import gdal, ogr, osr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import rasterio as rio
from rasterio.warp import calculate_default_transform, reproject, Resampling
from astropy.convolution import Gaussian2DKernel
from astropy.convolution import convolve
from pysheds.grid import Grid
from shapely import geometry, ops
import fiona
import geopandas as gpd
import seaborn as sns
import pyproj
from pyproj import Transformer
#%matplotlib widget

# %%
grdfile = '../../Documents/proposals/IFPEN-these-2021/DEM/tandemxdem.tif'
rio_array = rio.open(grdfile)

# %% [markdown]
# The artifacts apear as large negative values, so I thought to get rid of them just switch them to `nan`. So now I have gaps in my DEM.

# %%
data_array = rio_array.read(1).astype(float)
data_array[data_array < 0] = np.nan

# %%
fig=plt.figure()
plt.imshow(data_array, aspect='auto', cmap='terrain')
plt.title('Input DEM')
plt.colorbar(label='Elevation (m)')
plt.savefig('input.png')
plt.show()

# %% [markdown]
# Can I use the convolution in astropy to get rid of the nans? https://docs.astropy.org/en/stable/convolution/

# %%
# We smooth with a Gaussian kernel with x_stddev=1 (and y_stddev=1)
kernel = Gaussian2DKernel(x_stddev=2)
print('The kernel is an array of size {}'.format(np.shape(kernel)))
# Out:
# The kernel is an array of size (17, 17)

# %%
# astropy's convolution replaces the NaN pixels with a kernel-weighted interpolation from their neighbors
astropy_conv = convolve(data_array, kernel)

# %%
fig=plt.figure()
plt.imshow(astropy_conv, aspect='auto', cmap='terrain')
plt.title('Output DEM')
plt.colorbar(label='Elevation (m)')
plt.savefig('output.png')
plt.show()

# %% [markdown]
# All good, but the kernel is applied everywhere, so what else has it done?

# %%
scale = np.max(np.abs(astropy_conv-data_array))
fig=plt.figure()
plt.imshow(astropy_conv-data_array, aspect='auto', cmap='RdBu_r', vmin=-scale, vmax=scale)
plt.title('Difference')
plt.colorbar(label='Elevation (m)')
plt.savefig('diff.png')
plt.show()

# %% [markdown]
# So the maximum change in elevation from applying the convolution is 10 cm. Not so bad I think. Worth it for filling the holes?

# %% [markdown]
# ### Export my new DEM to a tif file

# %%
def array2raster(newRasterfn,rasterOrigin,pixelWidth,pixelHeight,array):
    cols = array.shape[1]
    rows = array.shape[0]
    originX = rasterOrigin[0]
    originY = rasterOrigin[1]

    driver = gdal.GetDriverByName('GTiff')
    driver.Register()
    outRaster = driver.Create(newRasterfn, cols, rows, 1, gdal.GDT_Float32)
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    outband = outRaster.GetRasterBand(1)
    outband.WriteArray(array)
    outRasterSRS = osr.SpatialReference()
    outRasterSRS.ImportFromEPSG(4326)
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()
    outband.SetNoDataValue(-9999)

# %%
newRasterfn = 'processed-tandem.tif'
rasterOrigin = (rio_array.transform[2], rio_array.transform[5])
pixelWidth = rio_array.transform[0]
pixelHeight = rio_array.transform[4]  # do the negative later?

array2raster(newRasterfn,rasterOrigin,pixelWidth,pixelHeight,astropy_conv)

# %% [markdown]
# ### Load in the new DEM and clip to my catchment

# %%
grdfile = 'processed-tandem.tif'
rio_array = rio.open(grdfile)

# %%
data_array = rio_array.read(1).astype(float)

# %%
fig=plt.figure()
plt.imshow(data_array, aspect='auto', cmap='terrain')
plt.colorbar()
plt.show()

# %% [markdown]
# Looks correct, so load it in as a `pysheds` grid object.

# %%
grid = Grid.from_raster('processed-tandem.tif', data_name='dem')

# %%
fig, ax = plt.subplots(figsize=(8,6))
fig.patch.set_alpha(0)

plt.imshow(grid.dem, extent=grid.extent, cmap='cubehelix', zorder=1)
plt.colorbar(label='Elevation (m)')
plt.grid(zorder=0)
plt.title('Digital elevation map')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.tight_layout()

# %% [markdown]
# Following the examples I extract the flow direction and accumulation. The pit filling and resolving of flats is perhaps redundant given what I did to the DEM.

# %%
grid.fill_depressions('dem', out_name='flooded_dem')
grid.resolve_flats('flooded_dem', out_name='inflated_dem')

# %%
#N    NE    E    SE    S    SW    W    NW
dirmap = (64,  128,  1,   2,    4,   8,    16,  32)

# %%
grid.flowdir(data='inflated_dem', out_name='dir', dirmap=dirmap)
grid.accumulation(data='dir', out_name='acc')

# %%
print('directions shape = {}, accumulation shape = {}'.format(grid.dir.shape, grid.acc.shape))
# Out:
# directions shape = (1756, 2506), accumulation shape = (1756, 2506)

# %%
fig = plt.figure(figsize=(8,6))
fig.patch.set_alpha(0)

plt.imshow(grid.dir, extent=grid.extent, zorder=1, cmap='viridis')
boundaries = ([0] + sorted(list(dirmap)))
plt.colorbar(boundaries= boundaries,
             values=sorted(dirmap))
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Flow direction grid')
plt.grid(zorder=-1)
plt.tight_layout()

# %%
fig = plt.figure(figsize=(8,6))
fig.patch.set_alpha(0)

plt.imshow(grid.acc+1, extent=grid.extent, zorder=1, cmap='viridis', norm=colors.LogNorm(vmin=1, vmax=grid.acc.max()))
plt.colorbar()
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Accumulation')
plt.grid(zorder=-1)
plt.tight_layout()

# %%
# Delineate catchment at point of high accumulation
y, x = np.unravel_index(np.argsort(grid.acc.ravel())[-2], grid.acc.shape)
grid.catchment(x, y, data='dir', out_name='catch',
               dirmap=dirmap, xytype='index')

# %%
grid.accumulation(data='catch', out_name='acc_catch')

# %%
print('catchment shape = {}, accumulation shape = {}'.format(grid.catch.shape, grid.acc.shape))
# Out:
# catchment shape = (1756, 2506), accumulation shape = (1756, 2506)

# %%
branches = grid.extract_river_network('catch', 'acc_catch', threshold=500)

# %%
# %matplotlib widget
for branch in branches['features']:
    line = np.asarray(branch['geometry']['coordinates'])
    plt.plot(line[:, 0], line[:, 1])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Now I use the plot above to find the x, y coordinates of the pour point for my catchment: 85.881920, 27.873076

# %%
grid = Grid.from_raster('test.tif', data_name='dem2')
grid.fill_depressions('dem2', out_name='flooded_dem2')
grid.resolve_flats('flooded_dem2', out_name='inflated_dem2')
grid.flowdir(data='inflated_dem2', out_name='dir2', dirmap=dirmap)
grid.accumulation(data='dir2', out_name='acc2')

# %%
y, x = 27.873076, 85.881920
grid.catchment(x, y, data='dir2', out_name='catch',
               dirmap=dirmap, xytype='label')

# %%
grid.clip_to('catch')

# %%
# Get a view of the catchment
catchView = grid.view('dem2', nodata=np.nan)

# %%
# Plot the catchment
fig, ax = plt.subplots(figsize=(8,6))
fig.patch.set_alpha(0)

plt.grid('on', zorder=0)
plt.imshow(catchView, extent=grid.extent, cmap='cubehelix', zorder=1)
plt.colorbar(label='Elevation (m)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Kahule Khole Catchment')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 1.0, 'Kahule Khole Catchment')

# %% [markdown]
# Now I have the catchment!

# %%
grid.to_raster('dem2', 'KauleyKhola.tif', view=True, apply_mask=True, blockxsize=16, blockysize=16)

# %% [markdown]
# ### Check

# %%
grdfile = 'KauleyKhola.tif'
rio_array = rio.open(grdfile)

# %%
data_array = rio_array.read(1).astype(float)
data_array[data_array < 0] = np.nan

# %%
fig=plt.figure()
plt.imshow(data_array, aspect='auto', cmap='terrain')
plt.colorbar()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Create shapefile of the catchment for MODFLOW
# https://github.com/mdbartos/pysheds/blob/master/recipes/write_shapefile.ipynb

# %%
# Calling grid.polygonize without arguments will default to the catchment mask
shapes = grid.polygonize()

# %% [markdown]
# Create a schema and write to file using `fiona`

# %%
schema = {
    'geometry': 'Polygon',
    'properties': {'LABEL': 'float:16'}
}

with fiona.open('catchment.shp', 'w',
                driver='ESRI Shapefile',
                crs=grid.crs.srs,
                schema=schema) as c:
    i = 0
    for shape, value in shapes:
        rec = {}
        rec['geometry'] = shape
        rec['properties'] = {'LABEL' : str(value)}
        rec['id'] = str(i)
        c.write(rec)
        i += 1

# %% [markdown]
# Read in the shapefile and check it is correct

# %%
shp = gpd.read_file('catchment.shp')
fig, ax = plt.subplots(figsize=(6,6))
shp.plot(ax=ax)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Catchment polygon')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 1.0, 'Catchment polygon')

# %% [markdown]
# Now extract the river network for the catchment and write to a shape file

# %%
# grid.extract_river_network outputs geojson, which is a little different
grid.accumulation(data='catch', dirmap=dirmap, pad_inplace=False, out_name='acc')
branches = grid.extract_river_network('catch', 'acc', threshold=500, dirmap=dirmap)

schema = {
    'geometry': 'LineString',
    'properties': {}
}

with fiona.open('rivers.shp', 'w',
                driver='ESRI Shapefile',
                crs=grid.crs.srs,
                schema=schema) as c:
    i = 0
    for branch in branches['features']:
        rec = {}
        rec['geometry'] = branch['geometry']
        rec['properties'] = {}
        rec['id'] = str(i)
        c.write(rec)
        i += 1

# %% [markdown]
# Check the shapefile contains the rivers

# %%
shp = gpd.read_file('rivers.shp')

fig, ax = plt.subplots(figsize=(6,6))
shp.plot(ax=ax)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('River network')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 1.0, 'River network')

# %% [markdown]
# ### Need to reproject the DEM for MODLFOW from lat/long to meters and save as grd file

# %%
with rio.open('processed-tandem.tif') as src:
    print(src.crs)
# Out:
# EPSG:4326

# %%
wgs84=pyproj.CRS("EPSG:4326")
UTM45N=pyproj.CRS("EPSG:32645")
transformer = Transformer.from_crs(wgs84, UTM45N)
transformer.transform(27.9, 85.85)
# Out:
# (386820.5856950898, 3086656.473051696)

# %%
dst_crs = 'EPSG:32645'

# %%
with rio.open('processed-tandem.tif') as src:
    transform, width, height = calculate_default_transform(
        src.crs, dst_crs, src.width, src.height, *src.bounds)
    kwargs = src.meta.copy()
    kwargs.update({
        'crs': dst_crs,
        'transform': transform,
        'width': width,
        'height': height
    })

    with rio.open('projected_KauleyKhola.tif', 'w', **kwargs) as dst:
        for i in range(1, src.count + 1):
            reproject(
                source=rio.band(src, i),
                destination=rio.band(dst, i),
                src_transform=src.transform,
                src_crs=src.crs,
                dst_transform=transform,
                dst_crs=dst_crs,
                resampling=Resampling.nearest)

# %%
ds = gdal.Open('projected_KauleyKhola.tif')
ds = gdal.Translate('projected_KauleyKhola.grd', ds, format='GSAG')
